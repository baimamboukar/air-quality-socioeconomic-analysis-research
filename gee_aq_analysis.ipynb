# %%
import ee
import geemap
import pandas as pd
import matplotlib.pyplot as plt

ee.Initialize()

# Load Rwanda sector boundaries
sectors = ee.FeatureCollection("projects/ml-for-earth-observation/assets/rwa_sector")

# Print basic info about the sectors dataset
print(f"Number of sectors --> {sectors.size().getInfo()}")
print(f"First sector properties --> {sectors.first().toDictionary().getInfo()}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Number of sectors --> 416
# First sector properties --> {'Dist_ID': 11, 'District': 'Nyarugenge', 'Name': 'Gitega', 'Prov_ID': 1, 'Province': 'Kigali City', 'Sect_ID': 1101}

# %%
# Define the time period
start_date = '2020-01-01'
end_date = '2025-01-31'

# Load Sentinel-5P collections for different pollutants
no2 = ee.ImageCollection(
    'COPERNICUS/S5P/NRTI/L3_NO2').select('NO2_column_number_density')
co = ee.ImageCollection(
    'COPERNICUS/S5P/NRTI/L3_CO').select('CO_column_number_density')
so2 = ee.ImageCollection(
    'COPERNICUS/S5P/NRTI/L3_SO2').select('SO2_column_number_density')
o3 = ee.ImageCollection(
    'COPERNICUS/S5P/NRTI/L3_O3').select('O3_column_number_density')
aer = ee.ImageCollection("COPERNICUS/S5P/OFFL/L3_AER_AI") 
ch4 = ee.ImageCollection("COPERNICUS/S5P/OFFL/L3_CH4")
# Filter collections by date and Rwanda boundary
rwandaExtent = sectors.geometry().bounds()
no2 = no2.filterDate(start_date, end_date).filterBounds(rwandaExtent)
co = co.filterDate(start_date, end_date).filterBounds(rwandaExtent)
so2 = so2.filterDate(start_date, end_date).filterBounds(rwandaExtent)
o3 = o3.filterDate(start_date, end_date).filterBounds(rwandaExtent)
aer = aer.filterDate(start_date, end_date).filterBounds(rwandaExtent)
ch4 = ch4.filterDate(start_date, end_date).filterBounds(rwandaExtent)


# Print collection sizes
print(f"NO2 collection size: {no2.size().getInfo()}")
print(f"CO collection size: {co.size().getInfo()}")
print(f"SO2 collection size: {so2.size().getInfo()}")
print(f"O3 collection size: {o3.size().getInfo()}")
print(f"AER collection size: {aer.size().getInfo()}")
print(f"CH4 collection size: {ch4.size().getInfo()}")


# Function to calculate mean value of a pollutant for each sector


def calculate_pollutant_by_sector(image_collection, band_name):
    # Get the mean image
    mean_image = image_collection.mean()

    # Use reduceRegions to get mean value for each sector
    sector_means = mean_image.reduceRegions(
        collection=sectors,
        reducer=ee.Reducer.mean(),
        scale=1000  # 5km resolution
    )

    return sector_means


# Calculate for each pollutant
no2_by_sector = calculate_pollutant_by_sector(no2, 'NO2_column_number_density')
co_by_sector = calculate_pollutant_by_sector(co, 'CO_column_number_density')
so2_by_sector = calculate_pollutant_by_sector(so2, 'SO2_column_number_density')
o3_by_sector = calculate_pollutant_by_sector(o3, 'O3_column_number_density')
aer_by_sector = calculate_pollutant_by_sector(aer, 'absorbing_aerosol_index')
ch4_by_sector = calculate_pollutant_by_sector(ch4, 'CH4_column_volume_mixing_ratio_dry_air')

# Export the first few features to check the structure
print("NO2 by sector sample:")
print(aer_by_sector.limit(3).getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# NO2 collection size: 980
# CO collection size: 608
# SO2 collection size: 649
# O3 collection size: 1150
# AER collection size: 5154
# CH4 collection size: 4613
# NO2 by sector sample:
# {'type': 'FeatureCollection', 'columns': {'Dist_ID': 'Float', 'District': 'String', 'Name': 'String', 'Prov_ID': 'Float', 'Province': 'String', 'Sect_ID': 'Float', 'absorbing_aerosol_index': 'Float', 'sensor_altitude': 'Float', 'sensor_azimuth_angle': 'Float', 'sensor_zenith_angle': 'Float', 'solar_azimuth_angle': 'Float', 'solar_zenith_angle': 'Float', 'system:index': 'String'}, 'features': [{'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': [[[30.04570996035956, -1.9413336267672765], [30.045821495227276, -1.941409933357362], [30.04585720399942, -1.9414323846165285], [30.04586610914853, -1.941450353517211], [30.045875014297046, -1.9414952447684195], [30.045897321250663, -1.9415266725156022], [30.045924124858033, -1.9415446160439096], [30.04595983360299, -1.9415536061212209], [30.046013352617848, -1.9415670595761163], [30.046303430598915, -1.9416792771398002], [30.04639265810769, -1.9417151817109144], [30.04669604882966, -1.9418273981164689], [30.047151177716874, -1.9420204649901467], [30.047374333144127, -1.9421147433879427], [30.047396639849655, -1.9421192486214034], [30.04759290343168, -1.9422000072083871], [30.04787407299801, -1.9423257284195083], [30.04810613222966, -1.9424604103716452], [30.048302394778627, -1.9425816171084136], [30.048396117539244, -1.9426624336894465], [30.04853004487053, -1.9427970877757128], [30.048601372802384, -1.942855452659563], [30.0486682922987, -1.9429228131377987], [30.04876651136752, -1.9431382852800005], [30.04887363531518, -1.9433762794846658], [30.04892265661592, -1.9434705240266528], [30.048944963065214, -1.9435109263105967], [30.049016378945225, -1.9436366623733492], [30.04909669972308, -1.943744405370498], [30.04911900614357, -1.9437578847051522], [30.049181517001855, -1.943789304720011], [30.049257341135192, -1.9438207237580845], [30.049333253393396, -1.943865602598753], [30.049373369610127, -1.9439150203287159], [30.04942247889657, -1.9439733661569916], [30.049435880350437, -1.9440002866205832], [30.049440288723133, -1.9440900742738545], [30.049440288723133, -1.944121484741042], [30.049444785263127, -1.94414396267156], [30.049417982355823, -1.9442247380941193], [30.049395675984826, -1.944278632187799], [30.049368961235253, -1.9443460095423901], [30.04937786615236, -1.9444088513708633], [30.049395675984826, -1.9445031244857038], [30.049395675984826, -1.9445479970888424], [30.049395675984826, -1.9445704334099703], [30.04939126761068, -1.9446557780397307], [30.049395675984826, -1.9446826802442674], [30.049400172526315, -1.9447186203325613], [30.049458186714787, -1.9448847474275393], [30.049493894523536, -1.9449655335823504], [30.049507295970304, -1.9449834799729884], [30.049516200878283, -1.9450777989569523], [30.049538507229332, -1.945261861979403], [30.049516200878283, -1.9454908296465427], [30.049560813576694, -1.9455357381435703], [30.049574215016808, -1.94554919734207], [30.04977946848575, -1.9457601722494948], [30.049922299323487, -1.9459891520019876], [30.050047232098805, -1.9461507823219362], [30.050056136971097, -1.9461552249645109], [30.050100749490753, -1.946218083401968], [30.05020337586333, -1.9464380987209295], [30.05026138970602, -1.9465592912890104], [30.050328308378052, -1.9466401170939214], [30.050319403523744, -1.9466805491360553], [30.050453240776942, -1.9467882862552799], [30.050546962041793, -1.946837628635893], [30.05069869689588, -1.947039706719764], [30.050752214029103, -1.9470935459418581], [30.050765615350734, -1.9470935428146972], [30.050752214029103, -1.9471249584588226], [30.050828125445204, -1.9472102906189241], [30.050993173115234, -1.9473314626151574], [30.05102447219652, -1.9473673981702222], [30.051109200095574, -1.9474616623398282], [30.05113150618293, -1.9474841169408834], [30.051314539392667, -1.947740017103582], [30.051372464590766, -1.9478118502634185], [30.051394858800716, -1.9478522534398688], [30.051430477930126, -1.9479285574010297], [30.051466185216245, -1.9479554964239647], [30.05149748418765, -1.9480318203759714], [30.051515 ...

# %%
# Function to export features to DataFrame
def ee_to_df(fc):
    features = fc.getInfo()['features']
    return pd.DataFrame([f['properties'] for f in features])


# Convert to pandas DataFrames
no2_df = ee_to_df(no2_by_sector)
co_df = ee_to_df(co_by_sector)
so2_df = ee_to_df(so2_by_sector)
o3_df = ee_to_df(o3_by_sector)
aer_df = ee_to_df(aer_by_sector)
ch4_df = ee_to_df(ch4_by_sector)


# Merge data into a single DataFrame
sector_df = no2_df[['Name', 'Dist_ID', 'District',
                    'Prov_ID', 'Province', 'Sect_ID', 'mean']]
sector_df.rename(columns={'mean': 'NO2_mean'}, inplace=True)

# Add other pollutants
sector_df['CO_mean'] = co_df['mean']
sector_df['SO2_mean'] = so2_df['mean']
sector_df['O3_mean'] = o3_df['mean']
sector_df['AER_mean'] = aer_df['mean']
sector_df['CH4_mean'] = ch4_df['mean']


# Preview the dataset
print(sector_df.head())
print(f"Total sectors with data: {len(sector_df)}")

# # Save to CSV
# sector_df.to_csv('rwanda_air_quality_by_sector_2023.csv', index=False)
# print("Data saved to rwanda_air_quality_by_sector_2023.csv")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mean'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 25
#      23 sector_df['SO2_mean'] = so2_df['mean']
#      24 sector_df['O3_mean'] = o3_df['mean']
# ---> 25 sector_df['AER_mean'] = aer_df['mean']
#      26 sector_df['CH4_mean'] = ch4_df['mean']
#      29 # Preview the dataset
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'mean'

# %%
# write df to csv
no2_monthly_df.to_csv('rwanda_no2_monthly_2023.csv', index=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def calculate_monthly_pollutant_stats_by_sector(image_collection, band_name, year, month):
    # Format dates
    month_str = f"{month:02d}"
    start_date = f"{year}-{month_str}-01"

    # Calculate end date (handle December correctly)
    if month == 12:
        end_date = f"{year+1}-01-01"
    else:
        end_date = f"{year}-{month+1:02d}-01"

    # Filter collection to month
    monthly_collection = image_collection.filterDate(start_date, end_date)

    # Check if collection is empty
    collection_size = monthly_collection.size().getInfo()
    if collection_size == 0:
        print(f"No data for {band_name} in {year}-{month_str}")
        # Create empty dataframe with right structure
        empty_df = pd.DataFrame(columns=[
            'Dist_ID', 'District', 'Name', 'Prov_ID', 'Province', 'Sect_ID',
            f'{band_name}_mean', f'{band_name}_min', f'{band_name}_max',
            'year', 'month', 'date'
        ])
        return empty_df

    try:
        # Calculate statistics
        mean_image = monthly_collection.mean()

        # Use reduceRegions to get mean value for each sector
        sector_stats = mean_image.reduceRegions(
            collection=sectors,
            reducer=ee.Reducer.mean(),
            scale=1000
        )

        # Convert to DataFrame
        stats_df = ee_to_df(sector_stats)

        # Rename columns
        if 'mean' in stats_df.columns:
            stats_df.rename(
                columns={'mean': f'{band_name}_mean'}, inplace=True)

        # Add min/max columns with placeholder values if not present
        if f'{band_name}_min' not in stats_df.columns:
            stats_df[f'{band_name}_min'] = stats_df[f'{band_name}_mean']
        if f'{band_name}_max' not in stats_df.columns:
            stats_df[f'{band_name}_max'] = stats_df[f'{band_name}_mean']

        # Add date
        stats_df['year'] = year
        stats_df['month'] = month
        stats_df['date'] = f"{year}-{month_str}"

        return stats_df

    except Exception as e:
        print(f"Error processing {band_name} for {year}-{month_str}: {e}")
        # Get all sector IDs
        all_sectors_df = ee_to_df(sectors)

        # Create DataFrame with zeros for all sectors
        empty_df = pd.DataFrame(
            all_sectors_df[['Dist_ID', 'District', 'Name', 'Prov_ID', 'Province', 'Sect_ID']])
        empty_df[f'{band_name}_mean'] = 0
        empty_df[f'{band_name}_min'] = 0
        empty_df[f'{band_name}_max'] = 0
        empty_df['year'] = year
        empty_df['month'] = month
        empty_df['date'] = f"{year}-{month_str}"

        return empty_df

start_date = '2018-01'
end_date = '2025-01'

# Get data for each pollutant
no2_all = calculate_pollutant_stats_by_sector_range(
    no2, 'NO2', start_date, end_date)
co_all = calculate_pollutant_stats_by_sector_range(
    co, 'CO', start_date, end_date)
so2_all = calculate_pollutant_stats_by_sector_range(
    so2, 'SO2', start_date, end_date)
o3_all = calculate_pollutant_stats_by_sector_range(
    o3, 'O3', start_date, end_date)

# Print summaries
for pollutant, df in [("NO2", no2_all), ("CO", co_all), ("SO2", so2_all), ("O3", o3_all)]:
    months = df['date'].nunique()
    sectors = df['Sect_ID'].nunique()
    print(f"{pollutant}: {months} months, {sectors} sectors, {len(df)} total records")

# Create combined dataset by merging on sector ID and date
df_combined = no2_all.merge(
    co_all[['Sect_ID', 'date', 'CO_mean', 'CO_min', 'CO_max']],
    on=['Sect_ID', 'date'], how='outer')

df_combined = df_combined.merge(
    so2_all[['Sect_ID', 'date', 'SO2_mean', 'SO2_min', 'SO2_max']],
    on=['Sect_ID', 'date'], how='outer')

df_combined = df_combined.merge(
    o3_all[['Sect_ID', 'date', 'O3_mean', 'O3_min', 'O3_max']],
    on=['Sect_ID', 'date'], how='outer')

# Save combined dataset
df_combined.to_csv('rwanda_air_quality_2020_2025.csv', index=False)
print(f"Combined data saved with {len(df_combined)} records")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing 2018-01...
# No data for NO2 in 2018-01
# Processing 2018-02...
# No data for NO2 in 2018-02
# Processing 2018-03...
# No data for NO2 in 2018-03
# Processing 2018-04...
# No data for NO2 in 2018-04
# Processing 2018-05...
# No data for NO2 in 2018-05
# Processing 2018-06...
# No data for NO2 in 2018-06
# Processing 2018-07...
# No data for NO2 in 2018-07
# Processing 2018-08...
# No data for NO2 in 2018-08
# Processing 2018-09...
# No data for NO2 in 2018-09
# Processing 2018-10...
# No data for NO2 in 2018-10
# Processing 2018-11...
# No data for NO2 in 2018-11
# Processing 2018-12...
# No data for NO2 in 2018-12
# Processing 2019-01...
# No data for NO2 in 2019-01
# Processing 2019-02...
# No data for NO2 in 2019-02
# Processing 2019-03...
# No data for NO2 in 2019-03
# Processing 2019-04...
# No data for NO2 in 2019-04
# Processing 2019-05...
# No data for NO2 in 2019-05
# Processing 2019-06...
# No data for NO2 in 2019-06
# Processing 2019-07...
# No data for NO2 in 2019-07
# Processing 2019-08...
# No data for NO2 in 2019-08
# Processing 2019-09...
# No data for NO2 in 2019-09
# Processing 2019-10...
# No data for NO2 in 2019-10
# Processing 2019-11...
# No data for NO2 in 2019-11
# Processing 2019-12...
# No data for NO2 in 2019-12
# Processing 2020-01...
# No data for NO2 in 2020-01
# Processing 2020-02...
# No data for NO2 in 2020-02
# Processing 2020-03...
# No data for NO2 in 2020-03
# Processing 2020-04...
# No data for NO2 in 2020-04
# Processing 2020-05...
# No data for NO2 in 2020-05
# Processing 2020-06...
# No data for NO2 in 2020-06
# Processing 2020-07...
# No data for NO2 in 2020-07
# Processing 2020-08...
# No data for NO2 in 2020-08
# Processing 2020-09...
# No data for NO2 in 2020-09
# Processing 2020-10...
# No data for NO2 in 2020-10
# Processing 2020-11...
# No data for NO2 in 2020-11
# Processing 2020-12...
# No data for NO2 in 2020-12
# Processing 2021-01...
# No data for NO2 in 2021-01
# Processing 2021-02...
# No data for NO2 in 2021-02
# Processing 2021-03...
# No data for NO2 in 2021-03
# Processing 2021-04...
# No data for NO2 in 2021-04
# Processing 2021-05...
# No data for NO2 in 2021-05
# Processing 2021-06...
# No data for NO2 in 2021-06
# Processing 2021-07...
# No data for NO2 in 2021-07
# Processing 2021-08...
# No data for NO2 in 2021-08
# Processing 2021-09...
# No data for NO2 in 2021-09
# Processing 2021-10...
# No data for NO2 in 2021-10
# Processing 2021-11...
# No data for NO2 in 2021-11
# Processing 2021-12...
# No data for NO2 in 2021-12
# Processing 2022-01...
# No data for NO2 in 2022-01
# Processing 2022-02...
# No data for NO2 in 2022-02
# Processing 2022-03...
# No data for NO2 in 2022-03
# Processing 2022-04...
# No data for NO2 in 2022-04
# Processing 2022-05...
# No data for NO2 in 2022-05
# Processing 2022-06...
# No data for NO2 in 2022-06
# Processing 2022-07...
# No data for NO2 in 2022-07
# Processing 2022-08...
# No data for NO2 in 2022-08
# Processing 2022-09...
# No data for NO2 in 2022-09
# Processing 2022-10...
# No data for NO2 in 2022-10
# Processing 2022-11...
# No data for NO2 in 2022-11
# Processing 2022-12...
# No data for NO2 in 2022-12
# Processing 2023-01...
# Error processing NO2 for 2023-01: Unrecognized argument type to convert to a FeatureCollection: 416
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# Cell In[21], line 32, in calculate_monthly_pollutant_stats_by_sector(image_collection, band_name, year, month)
#      31 # Use reduceRegions to get mean value for each sector
# ---> 32 sector_stats = mean_image.reduceRegions(
#      33     collection=sectors,
#      34     reducer=ee.Reducer.mean(),
#      35     scale=1000
#      36 )
#      38 # Convert to DataFrame
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\image.py:3359, in Image.reduceRegions(self, collection, reducer, scale, crs, crsTransform, tileScale)
#    3334 """Apply a reducer over the area of each feature in the given collection.
#    3335
#    3336 The reducer must have the same number of inputs as the input image has
#    (...)
#    3356   corresponding reducer outputs.
#    3357 """
# -> 3359 return apifunction.ApiFunction.call_(
#    3360     self.name() + '.reduceRegions',
#    3361     self,
#    3362     collection,
#    3363     reducer,
#    3364     scale,
#    3365     crs,
#    3366     crsTransform,
#    3367     tileScale,
#    3368 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\apifunction.py:84, in ApiFunction.call_(cls, name, *args, **kwargs)
#      73 """Call a named API function with positional and keyword arguments.
#      74
#      75 Args:
#    (...)
#      82   a recognized return type, the returned value will be cast to that type.
#      83 """
# ---> 84 return cls.lookup(name).call(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\function.py:62, in Function.call(self, *args, **kwargs)
#      51 """Calls the function with the given positional and keyword arguments.
#      52
#      53 Args:
#    (...)
#      60   to that type.
#      61 """
# ---> 62 return self.apply(self.nameArgs(args, kwargs))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\function.py:75, in Function.apply(self, named_args)
#      65 """Calls the function with a dictionary of named arguments.
#      66
#      67 Args:
#    (...)
#      73   to that type.
#      74 """
# ---> 75 result = computedobject.ComputedObject(self, self.promoteArgs(named_args))
#      76 return Function._promoter(result, self.getReturnType())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\function.py:103, in Function.promoteArgs(self, args)
#     102 if name in args:
# --> 103   promoted_args[name] = Function._promoter(args[name], arg_spec['type'])
#     104 elif not arg_spec.get('optional'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\__init__.py:323, in _Promote(arg, a_class)
#     322   else:
# --> 323     return FeatureCollection(arg)
#     324 elif a_class == 'ImageCollection':
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\computedobject.py:28, in ComputedObjectMetaclass.__call__(cls, *args, **kwargs)
#      27 else:
# ---> 28   return type.__call__(cls, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\_utils.py:38, in accept_opt_prefix.<locals>.opt_fixed.<locals>.wrapper(*args, **kwargs)
#      37       kwargs[new_key] = old_key_val
# ---> 38 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\deprecation.py:124, in WarnForDeprecatedAsset.<locals>.Decorator.<locals>.Wrapper(*args, **kwargs)
#     123     _IssueAssetDeprecationWarning(asset)
# --> 124 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\featurecollection.py:100, in FeatureCollection.__init__(self, args, column)
#      99 else:
# --> 100   raise ee_exception.EEException(
#     101       'Unrecognized argument type to convert to a FeatureCollection: %s' %
#     102       args)
#
# EEException: Unrecognized argument type to convert to a FeatureCollection: 416
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 80
#      77 end_date = '2025-01'
#      79 # Get data for each pollutant
# ---> 80 no2_all = calculate_pollutant_stats_by_sector_range(
#      81     no2, 'NO2', start_date, end_date)
#      82 co_all = calculate_pollutant_stats_by_sector_range(
#      83     co, 'CO', start_date, end_date)
#      84 so2_all = calculate_pollutant_stats_by_sector_range(
#      85     so2, 'SO2', start_date, end_date)
#
# Cell In[19], line 19, in calculate_pollutant_stats_by_sector_range(image_collection, band_name, start_date, end_date)
#      16 print(f"Processing {year}-{month:02d}...")
#      18 # Get stats for current month
# ---> 19 month_stats = calculate_monthly_pollutant_stats_by_sector(
#      20     image_collection, band_name, year, month)
#      22 if not month_stats.empty:
#      23     all_results.append(month_stats)
#
# Cell In[21], line 62, in calculate_monthly_pollutant_stats_by_sector(image_collection, band_name, year, month)
#      60 print(f"Error processing {band_name} for {year}-{month_str}: {e}")
#      61 # Get all sector IDs
# ---> 62 all_sectors_df = ee_to_df(sectors)
#      64 # Create DataFrame with zeros for all sectors
#      65 empty_df = pd.DataFrame(
#      66     all_sectors_df[['Dist_ID', 'District', 'Name', 'Prov_ID', 'Province', 'Sect_ID']])
#
# Cell In[15], line 3, in ee_to_df(fc)
#       2 def ee_to_df(fc):
# ----> 3     features = fc.getInfo()['features']
#       4     return pd.DataFrame([f['properties'] for f in features])
#
# AttributeError: 'int' object has no attribute 'getInfo'

# %%
# Load Rwanda sector boundaries
# sectors = ee.FeatureCollection("projects/ml-for-earth-observation/assets/rwa_sector")

# Print basic info about the sectors dataset
print(f"Number of sectors: {sectors.size().getInfo()}")
print(f"First sector properties: {sectors.first().toDictionary().getInfo()}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Number of sectors: 416
# First sector properties: {'Dist_ID': 11, 'District': 'Nyarugenge', 'Name': 'Gitega', 'Prov_ID': 1, 'Province': 'Kigali City', 'Sect_ID': 1101}

# %%
def ee_to_df(fc):
    features = fc.getInfo()['features']
    return pd.DataFrame([f['properties'] for f in features])

# Function to calculate monthly pollutant stats by sector
def calculate_monthly_pollutant_stats_by_sector(image_collection, band_name, year, month):
    # Format dates
    month_str = f"{month:02d}"
    start_date = f"{year}-{month_str}-01"

    # Calculate end date (handle December correctly)
    if month == 12:
        end_date = f"{year+1}-01-01"
    else:
        end_date = f"{year}-{month+1:02d}-01"

    # Filter collection to month
    monthly_collection = image_collection.filterDate(start_date, end_date)

    # Check if collection is empty
    collection_size = monthly_collection.size().getInfo()
    if collection_size == 0:
        print(f"No data for {band_name} in {year}-{month_str}")
        # Return empty DataFrame with correct structure
        return pd.DataFrame(columns=[
            'Dist_ID', 'District', 'Name', 'Prov_ID', 'Province', 'Sect_ID',
            f'{band_name}_mean', f'{band_name}_min', f'{band_name}_max',
            'year', 'month', 'date'
        ])

    try:
        # Calculate statistics
        mean_image = monthly_collection.mean()

        # Use reduceRegions to get mean value for each sector
        sector_stats = mean_image.reduceRegions(
            collection=sectors,
            reducer=ee.Reducer.mean(),
            scale=1200
        )

        # Convert to DataFrame
        stats_df = ee_to_df(sector_stats)

        # Rename columns
        if 'mean' in stats_df.columns:
            stats_df.rename(
                columns={'mean': f'{band_name}_mean'}, inplace=True)

        # Add date columns
        stats_df['year'] = year
        stats_df['month'] = month
        stats_df['date'] = f"{year}-{month_str}"

        return stats_df

    except Exception as e:
        print(f"Error processing {band_name} for {year}-{month_str}: {e}")
        return pd.DataFrame()  # Return empty DataFrame
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Function to get pollutant stats for a date range

def calculate_pollutant_stats_by_sector_range(image_collection, band_name, start_year, end_year):
    all_results = []

    # Loop through each year and month
    for year in range(start_year, end_year + 1):
        for month in range(1, 13):
            # Skip future months in 2025
            if year == 2025 and month > 1:
                continue

            print(f"Processing {band_name}: {year}-{month:02d}...")

            # Get stats for current month
            month_stats = calculate_monthly_pollutant_stats_by_sector(
                image_collection, band_name, year, month)

            if not month_stats.empty:
                all_results.append(month_stats)

    # Combine all months
    if all_results:
        combined_df = pd.concat(all_results)
        return combined_df
    else:
        # Return empty DataFrame with correct columns
        return pd.DataFrame(columns=[
            'Dist_ID', 'District', 'Name', 'Prov_ID', 'Province', 'Sect_ID',
            f'{band_name}_mean', 'year', 'month', 'date'
        ])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def collect_air_quality_data(start_year, end_year):
    # Define date strings for filtering
    start_date = f"{start_year}-01-01"
    end_date = f"{end_year}-01-31"

    # Load pollutant collections
    no2 = ee.ImageCollection(
        'COPERNICUS/S5P/NRTI/L3_NO2').select('NO2_column_number_density')
    co = ee.ImageCollection(
        'COPERNICUS/S5P/NRTI/L3_CO').select('CO_column_number_density')
    so2 = ee.ImageCollection(
        'COPERNICUS/S5P/NRTI/L3_SO2').select('SO2_column_number_density')
    o3 = ee.ImageCollection(
        'COPERNICUS/S5P/NRTI/L3_O3').select('O3_column_number_density')
    aer = ee.ImageCollection(
        "COPERNICUS/S5P/OFFL/L3_AER_AI").select('absorbing_aerosol_index')
    ch4 = ee.ImageCollection(
        "COPERNICUS/S5P/OFFL/L3_CH4").select('CH4_column_volume_mixing_ratio_dry_air')

    # Filter by date and location
    rwandaExtent = sectors.geometry().bounds()
    no2 = no2.filterDate(start_date, end_date).filterBounds(rwandaExtent)
    co = co.filterDate(start_date, end_date).filterBounds(rwandaExtent)
    so2 = so2.filterDate(start_date, end_date).filterBounds(rwandaExtent)
    o3 = o3.filterDate(start_date, end_date).filterBounds(rwandaExtent)
    aer = aer.filterDate(start_date, end_date).filterBounds(rwandaExtent)
    ch4 = ch4.filterDate(start_date, end_date).filterBounds(rwandaExtent)

    # Print collection sizes
    print(f"NO2 collection size: {no2.size().getInfo()}")
    print(f"CO collection size: {co.size().getInfo()}")
    print(f"SO2 collection size: {so2.size().getInfo()}")
    print(f"O3 collection size: {o3.size().getInfo()}")
    print(f"AER collection size: {aer.size().getInfo()}")
    print(f"CH4 collection size: {ch4.size().getInfo()}")

    # Get data for each pollutant
    print("\nCollecting monthly data for all pollutants...")
    no2_all = calculate_pollutant_stats_by_sector_range(
        no2, 'NO2', start_year, end_year)
    co_all = calculate_pollutant_stats_by_sector_range(
        co, 'CO', start_year, end_year)
    so2_all = calculate_pollutant_stats_by_sector_range(
        so2, 'SO2', start_year, end_year)
    o3_all = calculate_pollutant_stats_by_sector_range(
        o3, 'O3', start_year, end_year)
    aer_all = calculate_pollutant_stats_by_sector_range(
        aer, 'AER', start_year, end_year)
    ch4_all = calculate_pollutant_stats_by_sector_range(
        ch4, 'CH4', start_year, end_year)

    # Print summaries
    print("\nData collection summary:")
    for pollutant, df in [("NO2", no2_all), ("CO", co_all), ("SO2", so2_all),
                          ("O3", o3_all), ("AER", aer_all), ("CH4", ch4_all)]:
        if not df.empty:
            months = df['date'].nunique()
            sectorsx = df['Sect_ID'].nunique()
            print(
                f"{pollutant}: {months} months, {sectorsx} sectors, {len(df)} total records")
        else:
            print(f"{pollutant}: No data collected")

    # Return all the datasets
    return {
        'NO2': no2_all,
        'CO': co_all,
        'SO2': so2_all,
        'O3': o3_all,
        'AER': aer_all,
        'CH4': ch4_all
    }
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def merge_air_quality_data(pollutant_datasets, start_year, end_year):
    """
    Merge multiple pollutant datasets into a single DataFrame.
    
    Args:
        pollutant_datasets: Dictionary with pollutant names as keys and DataFrames as values
        start_year: Starting year for the filename
        end_year: Ending year for the filename
        
    Returns:
        Combined DataFrame with all pollutants
    """
    print("\nMerging datasets...")

    # Create a list of pollutant names and their corresponding DataFrames
    pollutant_data = [
        (name, df) for name, df in pollutant_datasets.items()
    ]

    # Filter to only non-empty DataFrames
    non_empty_pollutant_data = [(name, df)
                                for name, df in pollutant_data if not df.empty]

    if len(non_empty_pollutant_data) > 0:
        # Start with the first non-empty dataset
        first_name, merged_df = non_empty_pollutant_data[0]

        # Merge remaining datasets one by one
        for pollutant, df in non_empty_pollutant_data[1:]:
            cols_to_use = ['Sect_ID', 'date', f'{pollutant}_mean']

            # Make sure the required columns exist
            if all(col in df.columns for col in cols_to_use):
                merged_df = merged_df.merge(
                    df[cols_to_use], on=['Sect_ID', 'date'], how='outer')
            else:
                print(
                    f"Warning: Required columns not found in {pollutant} dataset. Columns: {df.columns.tolist()}")

        # Save combined dataset
        filename = f'rwanda_air_quality_{start_year}_{end_year}.csv'
        merged_df.to_csv(filename, index=False)
        print(
            f"\nCombined data saved to {filename} with {len(merged_df)} records")
        return merged_df
    else:
        print("No data to merge")
        return pd.DataFrame()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
data = collect_air_quality_data(2020, 2025)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# NO2 collection size: 3538
# CO collection size: 3119
# SO2 collection size: 3182
# O3 collection size: 3706
# AER collection size: 26296
# CH4 collection size: 24795
#
# Collecting monthly data for all pollutants...
# Processing NO2: 2020-01...
# Processing NO2: 2020-02...
# Processing NO2: 2020-03...
# Processing NO2: 2020-04...
# Processing NO2: 2020-05...
# Processing NO2: 2020-06...
# Processing NO2: 2020-07...
# Processing NO2: 2020-08...
# Processing NO2: 2020-09...
# Processing NO2: 2020-10...
# Processing NO2: 2020-11...
# Processing NO2: 2020-12...
# Processing NO2: 2021-01...
# Processing NO2: 2021-02...
# Processing NO2: 2021-03...
# Processing NO2: 2021-04...
# Processing NO2: 2021-05...
# Processing NO2: 2021-06...
# Processing NO2: 2021-07...
# Processing NO2: 2021-08...
# Processing NO2: 2021-09...
# Processing NO2: 2021-10...
# Processing NO2: 2021-11...
# Processing NO2: 2021-12...
# Processing NO2: 2022-01...
# Processing NO2: 2022-02...
# Processing NO2: 2022-03...
# Processing NO2: 2022-04...
# Processing NO2: 2022-05...
# Processing NO2: 2022-06...
# Processing NO2: 2022-07...
# Processing NO2: 2022-08...
# Processing NO2: 2022-09...
# Processing NO2: 2022-10...
# Processing NO2: 2022-11...
# Processing NO2: 2022-12...
# Processing NO2: 2023-01...
# Processing NO2: 2023-02...
# Processing NO2: 2023-03...
# Processing NO2: 2023-04...
# Processing NO2: 2023-05...
# Processing NO2: 2023-06...
# Processing NO2: 2023-07...
# Processing NO2: 2023-08...
# Processing NO2: 2023-09...
# Processing NO2: 2023-10...
# Processing NO2: 2023-11...
# Processing NO2: 2023-12...
# Processing NO2: 2024-01...
# Processing NO2: 2024-02...
# Processing NO2: 2024-03...
# Processing NO2: 2024-04...
# Processing NO2: 2024-05...
# Processing NO2: 2024-06...
# Processing NO2: 2024-07...
# Processing NO2: 2024-08...
# Processing NO2: 2024-09...
# Processing NO2: 2024-10...
# Processing NO2: 2024-11...
# Processing NO2: 2024-12...
# Processing NO2: 2025-01...
# Processing CO: 2020-01...
# Processing CO: 2020-02...
# Processing CO: 2020-03...
# Processing CO: 2020-04...
# Processing CO: 2020-05...
# Processing CO: 2020-06...
# Processing CO: 2020-07...
# Processing CO: 2020-08...
# Processing CO: 2020-09...
# Processing CO: 2020-10...
# Processing CO: 2020-11...
# Processing CO: 2020-12...
# Processing CO: 2021-01...
# Processing CO: 2021-02...
# Processing CO: 2021-03...
# Processing CO: 2021-04...
# Processing CO: 2021-05...
# Processing CO: 2021-06...
# Processing CO: 2021-07...
# Processing CO: 2021-08...
# Processing CO: 2021-09...
# Processing CO: 2021-10...
# Processing CO: 2021-11...
# Processing CO: 2021-12...
# Processing CO: 2022-01...
# Processing CO: 2022-02...
# Processing CO: 2022-03...
# Processing CO: 2022-04...
# Processing CO: 2022-05...
# Processing CO: 2022-06...
# Processing CO: 2022-07...
# Processing CO: 2022-08...
# Processing CO: 2022-09...
# Processing CO: 2022-10...
# Processing CO: 2022-11...
# Processing CO: 2022-12...
# Processing CO: 2023-01...
# Processing CO: 2023-02...
# Processing CO: 2023-03...
# Processing CO: 2023-04...
# Processing CO: 2023-05...
# Processing CO: 2023-06...
# Processing CO: 2023-07...
# Processing CO: 2023-08...
# Processing CO: 2023-09...
# Processing CO: 2023-10...
# Processing CO: 2023-11...
# Processing CO: 2023-12...
# Processing CO: 2024-01...
# Processing CO: 2024-02...
# Processing CO: 2024-03...
# Processing CO: 2024-04...
# Processing CO: 2024-05...
# Processing CO: 2024-06...
# Processing CO: 2024-07...
# Processing CO: 2024-08...
# Processing CO: 2024-09...
# Processing CO: 2024-10...
# Processing CO: 2024-11...
# Processing CO: 2024-12...
# Processing CO: 2025-01...
# Processing SO2: 2020-01...
# Processing SO2: 2020-02...
# Processing SO2: 2020-03...
# Processing SO2: 2020-04...
# Processing SO2: 2020-05...
# Processing SO2: 2020-06...
# Processing SO2: 2020-07...
# Processing SO2: 2020-08...
# Processing SO2: 2020-09...
# Processing SO2: 2020-10...
# Processing SO2: 2020-11...
# Processing SO2: 2020-12...
# Processing SO2: 2021-01...
# Processing SO2: 2021-02...
# Processing SO2: 2021-03...
# Processing SO2: 2021-04...
# Processing SO2: 2021-05...
# Processing SO2: 2021-06...
# Processing SO2: 2021-07...
# Processing SO2: 2021-08...
# Processing SO2: 2021-09...
# Processing SO2: 2021-10...
# Processing SO2: 2021-11...
# Processing SO2: 2021-12...
# Processing SO2: 2022-01...
# Processing SO2: 2022-02...
# Processing SO2: 2022-03...
# Processing SO2: 2022-04...
# Processing SO2: 2022-05...
# Processing SO2: 2022-06...
# Processing SO2: 2022-07...
# Processing SO2: 2022-08...
# Processing SO2: 2022-09...
# Processing SO2: 2022-10...
# Processing SO2: 2022-11...
# Processing SO2: 2022-12...
# Processing SO2: 2023-01...
# Processing SO2: 2023-02...
# Processing SO2: 2023-03...
# Processing SO2: 2023-04...
# Processing SO2: 2023-05...
# Processing SO2: 2023-06...
# Processing SO2: 2023-07...
# Processing SO2: 2023-08...
# Processing SO2: 2023-09...
# Processing SO2: 2023-10...
# Processing SO2: 2023-11...
# Processing SO2: 2023-12...
# Processing SO2: 2024-01...
# Processing SO2: 2024-02...
# Processing SO2: 2024-03...
# Processing SO2: 2024-04...
# Processing SO2: 2024-05...
# Processing SO2: 2024-06...
# Processing SO2: 2024-07...
# Processing SO2: 2024-08...
# Processing SO2: 2024-09...
# Processing SO2: 2024-10...
# Processing SO2: 2024-11...
# Processing SO2: 2024-12...
# Processing SO2: 2025-01...
# Processing O3: 2020-01...
# Processing O3: 2020-02...
# Processing O3: 2020-03...
# Processing O3: 2020-04...
# Processing O3: 2020-05...
# Processing O3: 2020-06...
# Processing O3: 2020-07...
# Processing O3: 2020-08...
# Processing O3: 2020-09...
# Processing O3: 2020-10...
# Processing O3: 2020-11...
# Processing O3: 2020-12...
# Processing O3: 2021-01...
# Processing O3: 2021-02...
# Processing O3: 2021-03...
# Processing O3: 2021-04...
# Processing O3: 2021-05...
# Processing O3: 2021-06...
# Processing O3: 2021-07...
# Processing O3: 2021-08...
# Processing O3: 2021-09...
# Processing O3: 2021-10...
# Processing O3: 2021-11...
# Processing O3: 2021-12...
# Processing O3: 2022-01...
# Processing O3: 2022-02...
# Processing O3: 2022-03...
# Processing O3: 2022-04...
# Processing O3: 2022-05...
# Processing O3: 2022-06...
# Processing O3: 2022-07...
# Processing O3: 2022-08...
# Processing O3: 2022-09...
# Processing O3: 2022-10...
# Processing O3: 2022-11...
# Processing O3: 2022-12...
# Processing O3: 2023-01...
# Processing O3: 2023-02...
# Processing O3: 2023-03...
# Processing O3: 2023-04...
# Processing O3: 2023-05...
# Processing O3: 2023-06...
# Processing O3: 2023-07...
# Processing O3: 2023-08...
# Processing O3: 2023-09...
# Processing O3: 2023-10...
# Processing O3: 2023-11...
# Processing O3: 2023-12...
# Processing O3: 2024-01...
# Processing O3: 2024-02...
# Processing O3: 2024-03...
# Processing O3: 2024-04...
# Processing O3: 2024-05...
# Processing O3: 2024-06...
# Processing O3: 2024-07...
# Processing O3: 2024-08...
# Processing O3: 2024-09...
# Processing O3: 2024-10...
# Processing O3: 2024-11...
# Processing O3: 2024-12...
# Processing O3: 2025-01...
# Processing AER: 2020-01...
# Processing AER: 2020-02...
# Processing AER: 2020-03...
# Processing AER: 2020-04...
# Processing AER: 2020-05...
# Processing AER: 2020-06...
# Processing AER: 2020-07...
# Processing AER: 2020-08...
# Processing AER: 2020-09...
# Processing AER: 2020-10...
# Processing AER: 2020-11...
# Processing AER: 2020-12...
# Processing AER: 2021-01...
# Processing AER: 2021-02...
# Processing AER: 2021-03...
# Processing AER: 2021-04...
# Processing AER: 2021-05...
# Processing AER: 2021-06...
# Processing AER: 2021-07...
# Processing AER: 2021-08...
# Processing AER: 2021-09...
# Processing AER: 2021-10...
# Processing AER: 2021-11...
# Processing AER: 2021-12...
# Processing AER: 2022-01...
# Processing AER: 2022-02...
# Processing AER: 2022-03...
# Processing AER: 2022-04...
# Processing AER: 2022-05...
# Processing AER: 2022-06...
# Processing AER: 2022-07...
# Processing AER: 2022-08...
# Processing AER: 2022-09...
# Processing AER: 2022-10...
# Processing AER: 2022-11...
# Processing AER: 2022-12...
# Processing AER: 2023-01...
# Processing AER: 2023-02...
# Processing AER: 2023-03...
# Processing AER: 2023-04...
# Processing AER: 2023-05...
# Processing AER: 2023-06...
# Processing AER: 2023-07...
# Processing AER: 2023-08...
# Processing AER: 2023-09...
# Processing AER: 2023-10...
# Processing AER: 2023-11...
# Processing AER: 2023-12...
# Processing AER: 2024-01...
# Processing AER: 2024-02...
# Processing AER: 2024-03...
# Processing AER: 2024-04...
# Processing AER: 2024-05...
# Processing AER: 2024-06...
# Processing AER: 2024-07...
# Processing AER: 2024-08...
# Processing AER: 2024-09...
# Processing AER: 2024-10...
# Processing AER: 2024-11...
# Processing AER: 2024-12...
# Processing AER: 2025-01...
# Processing CH4: 2020-01...
# Processing CH4: 2020-02...
# Processing CH4: 2020-03...
# Processing CH4: 2020-04...
# Processing CH4: 2020-05...
# Processing CH4: 2020-06...
# Processing CH4: 2020-07...
# Processing CH4: 2020-08...
# Processing CH4: 2020-09...
# Processing CH4: 2020-10...
# Processing CH4: 2020-11...
# Processing CH4: 2020-12...
# Processing CH4: 2021-01...
# Processing CH4: 2021-02...
# Processing CH4: 2021-03...
# Processing CH4: 2021-04...
# Processing CH4: 2021-05...
# Processing CH4: 2021-06...
# Processing CH4: 2021-07...
# Processing CH4: 2021-08...
# Processing CH4: 2021-09...
# Processing CH4: 2021-10...
# Processing CH4: 2021-11...
# Processing CH4: 2021-12...
# Processing CH4: 2022-01...
# Processing CH4: 2022-02...
# Processing CH4: 2022-03...
# Processing CH4: 2022-04...
# Processing CH4: 2022-05...
# Processing CH4: 2022-06...
# Processing CH4: 2022-07...
# Processing CH4: 2022-08...
# Processing CH4: 2022-09...
# Processing CH4: 2022-10...
# Processing CH4: 2022-11...
# Processing CH4: 2022-12...
# Processing CH4: 2023-01...
# Processing CH4: 2023-02...
# Processing CH4: 2023-03...
# Processing CH4: 2023-04...
# Processing CH4: 2023-05...
# Processing CH4: 2023-06...
# Processing CH4: 2023-07...
# Processing CH4: 2023-08...
# Processing CH4: 2023-09...
# Processing CH4: 2023-10...
# Processing CH4: 2023-11...
# Processing CH4: 2023-12...
# Processing CH4: 2024-01...
# Processing CH4: 2024-02...
# Processing CH4: 2024-03...
# Processing CH4: 2024-04...
# Processing CH4: 2024-05...
# Processing CH4: 2024-06...
# Processing CH4: 2024-07...
# Processing CH4: 2024-08...
# Processing CH4: 2024-09...
# Processing CH4: 2024-10...
# Processing CH4: 2024-11...
# Processing CH4: 2024-12...
# Processing CH4: 2025-01...
#
# Data collection summary:
# NO2: 61 months, 416 sectors, 25376 total records
# CO: 61 months, 416 sectors, 25376 total records
# SO2: 61 months, 416 sectors, 25376 total records
# O3: 61 months, 416 sectors, 25376 total records
# AER: 61 months, 416 sectors, 25376 total records
# CH4: 61 months, 416 sectors, 25376 total records

# %%
dataset = merge_air_quality_data(data, 2020, 2025)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Merging datasets...
#
# Combined data saved to rwanda_air_quality_2020_2025.csv with 25376 records
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
dataset.to_csv('extracted.csv', index=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# NO2 collection size: 3538
# CO collection size: 3119
# SO2 collection size: 3182
# O3 collection size: 3706
# AER collection size: 26296
# CH4 collection size: 24795
#
# Collecting monthly data for all pollutants...
# Processing NO2: 2020-01...
# Processing NO2: 2020-02...
# Processing NO2: 2020-03...
# Processing NO2: 2020-04...
# Processing NO2: 2020-05...
# Processing NO2: 2020-06...
# Processing NO2: 2020-07...
# Processing NO2: 2020-08...
# Processing NO2: 2020-09...
# Processing NO2: 2020-10...
# Processing NO2: 2020-11...
# Processing NO2: 2020-12...
# Processing NO2: 2021-01...
# Processing NO2: 2021-02...
# Processing NO2: 2021-03...
# Processing NO2: 2021-04...
# Processing NO2: 2021-05...
# Processing NO2: 2021-06...
# Processing NO2: 2021-07...
# Processing NO2: 2021-08...
# Processing NO2: 2021-09...
# Processing NO2: 2021-10...
# Processing NO2: 2021-11...
# Processing NO2: 2021-12...
# Processing NO2: 2022-01...
# Processing NO2: 2022-02...
# Processing NO2: 2022-03...
# Processing NO2: 2022-04...
# Processing NO2: 2022-05...
# Processing NO2: 2022-06...
# Processing NO2: 2022-07...
# Processing NO2: 2022-08...
# Processing NO2: 2022-09...
# Processing NO2: 2022-10...
# Processing NO2: 2022-11...
# Processing NO2: 2022-12...
# Processing NO2: 2023-01...
# Processing NO2: 2023-02...
# Processing NO2: 2023-03...
# Processing NO2: 2023-04...
# Processing NO2: 2023-05...
# Processing NO2: 2023-06...
# Processing NO2: 2023-07...
# Processing NO2: 2023-08...
# Processing NO2: 2023-09...
# Processing NO2: 2023-10...
# Processing NO2: 2023-11...
# Processing NO2: 2023-12...
# Processing NO2: 2024-01...
# Processing NO2: 2024-02...
# Processing NO2: 2024-03...
# Processing NO2: 2024-04...
# Processing NO2: 2024-05...
# Processing NO2: 2024-06...
# Processing NO2: 2024-07...
# Processing NO2: 2024-08...
# Processing NO2: 2024-09...
# Processing NO2: 2024-10...
# Processing NO2: 2024-11...
# Processing NO2: 2024-12...
# Processing NO2: 2025-01...
# Processing CO: 2020-01...
# Processing CO: 2020-02...
# Processing CO: 2020-03...
# Processing CO: 2020-04...
# Processing CO: 2020-05...
# Processing CO: 2020-06...
# Processing CO: 2020-07...
# Processing CO: 2020-08...
# Processing CO: 2020-09...
# Processing CO: 2020-10...
# Processing CO: 2020-11...
# Processing CO: 2020-12...
# Processing CO: 2021-01...
# Processing CO: 2021-02...
# Processing CO: 2021-03...
# Processing CO: 2021-04...
# Processing CO: 2021-05...
# Processing CO: 2021-06...
# Processing CO: 2021-07...
# Processing CO: 2021-08...
# Processing CO: 2021-09...
# Processing CO: 2021-10...
# Processing CO: 2021-11...
# Processing CO: 2021-12...
# Processing CO: 2022-01...
# Processing CO: 2022-02...
# Processing CO: 2022-03...
# Processing CO: 2022-04...
# Processing CO: 2022-05...
# Processing CO: 2022-06...
# Processing CO: 2022-07...
# Processing CO: 2022-08...
# Processing CO: 2022-09...
# Processing CO: 2022-10...
# Processing CO: 2022-11...
# Processing CO: 2022-12...
# Processing CO: 2023-01...
# Processing CO: 2023-02...
# Processing CO: 2023-03...
# Processing CO: 2023-04...
# Processing CO: 2023-05...
# Processing CO: 2023-06...
# Processing CO: 2023-07...
# Processing CO: 2023-08...
# Processing CO: 2023-09...
# Processing CO: 2023-10...
# Processing CO: 2023-11...
# Processing CO: 2023-12...
# Processing CO: 2024-01...
# Processing CO: 2024-02...
# Processing CO: 2024-03...
# Processing CO: 2024-04...
# Processing CO: 2024-05...
# Processing CO: 2024-06...
# Processing CO: 2024-07...
# Processing CO: 2024-08...
# Processing CO: 2024-09...
# Processing CO: 2024-10...
# Processing CO: 2024-11...
# Processing CO: 2024-12...
# Processing CO: 2025-01...
# Processing SO2: 2020-01...
# Processing SO2: 2020-02...
# Processing SO2: 2020-03...
# Processing SO2: 2020-04...
# Processing SO2: 2020-05...
# Processing SO2: 2020-06...
# Processing SO2: 2020-07...
# Processing SO2: 2020-08...
# Processing SO2: 2020-09...
# Processing SO2: 2020-10...
# Processing SO2: 2020-11...
# Processing SO2: 2020-12...
# Processing SO2: 2021-01...
# Processing SO2: 2021-02...
# Processing SO2: 2021-03...
# Processing SO2: 2021-04...
# Processing SO2: 2021-05...
# Processing SO2: 2021-06...
# Processing SO2: 2021-07...
# Processing SO2: 2021-08...
# Processing SO2: 2021-09...
# Processing SO2: 2021-10...
# Processing SO2: 2021-11...
# Processing SO2: 2021-12...
# Processing SO2: 2022-01...
# Processing SO2: 2022-02...
# Processing SO2: 2022-03...
# Processing SO2: 2022-04...
# Processing SO2: 2022-05...
# Processing SO2: 2022-06...
# Processing SO2: 2022-07...
# Processing SO2: 2022-08...
# Processing SO2: 2022-09...
# Processing SO2: 2022-10...
# Processing SO2: 2022-11...
# Processing SO2: 2022-12...
# Processing SO2: 2023-01...
# Processing SO2: 2023-02...
# Processing SO2: 2023-03...
# Processing SO2: 2023-04...
# Processing SO2: 2023-05...
# Processing SO2: 2023-06...
# Processing SO2: 2023-07...
# Processing SO2: 2023-08...
# Processing SO2: 2023-09...
# Processing SO2: 2023-10...
# Processing SO2: 2023-11...
# Processing SO2: 2023-12...
# Processing SO2: 2024-01...
# Processing SO2: 2024-02...
# Processing SO2: 2024-03...
# Processing SO2: 2024-04...
# Processing SO2: 2024-05...
# Processing SO2: 2024-06...
# Processing SO2: 2024-07...
# Processing SO2: 2024-08...
# Processing SO2: 2024-09...
# Processing SO2: 2024-10...
# Processing SO2: 2024-11...
# Processing SO2: 2024-12...
# Processing SO2: 2025-01...
# Processing O3: 2020-01...
# Processing O3: 2020-02...
# Processing O3: 2020-03...
# Processing O3: 2020-04...
# Processing O3: 2020-05...
# Processing O3: 2020-06...
# Processing O3: 2020-07...
# Processing O3: 2020-08...
# Processing O3: 2020-09...
# Processing O3: 2020-10...
# Processing O3: 2020-11...
# Processing O3: 2020-12...
# Processing O3: 2021-01...
# Processing O3: 2021-02...
# Processing O3: 2021-03...
# Processing O3: 2021-04...
# Processing O3: 2021-05...
# Processing O3: 2021-06...
# Processing O3: 2021-07...
# Processing O3: 2021-08...
# Processing O3: 2021-09...
# Processing O3: 2021-10...
# Processing O3: 2021-11...
# Processing O3: 2021-12...
# Processing O3: 2022-01...
# Processing O3: 2022-02...
# Processing O3: 2022-03...
# Processing O3: 2022-04...
# Processing O3: 2022-05...
# Processing O3: 2022-06...
# Processing O3: 2022-07...
# Processing O3: 2022-08...
# Processing O3: 2022-09...
# Processing O3: 2022-10...
# Processing O3: 2022-11...
# Processing O3: 2022-12...
# Processing O3: 2023-01...
# Processing O3: 2023-02...
# Processing O3: 2023-03...
# Processing O3: 2023-04...
# Processing O3: 2023-05...
# Processing O3: 2023-06...
# Processing O3: 2023-07...
# Processing O3: 2023-08...
# Processing O3: 2023-09...
# Processing O3: 2023-10...
# Processing O3: 2023-11...
# Processing O3: 2023-12...
# Processing O3: 2024-01...
# Processing O3: 2024-02...
# Processing O3: 2024-03...
# Processing O3: 2024-04...
# Processing O3: 2024-05...
# Processing O3: 2024-06...
# Processing O3: 2024-07...
# Processing O3: 2024-08...
# Processing O3: 2024-09...
# Processing O3: 2024-10...
# Processing O3: 2024-11...
# Processing O3: 2024-12...
# Processing O3: 2025-01...
# Processing AER: 2020-01...
# Processing AER: 2020-02...
# Processing AER: 2020-03...
# Processing AER: 2020-04...
# Processing AER: 2020-05...
# Processing AER: 2020-06...
# Processing AER: 2020-07...
# Processing AER: 2020-08...
# Processing AER: 2020-09...
# Processing AER: 2020-10...
# Processing AER: 2020-11...
# Processing AER: 2020-12...
# Processing AER: 2021-01...
# Processing AER: 2021-02...
# Processing AER: 2021-03...
# Processing AER: 2021-04...
# Processing AER: 2021-05...
# Processing AER: 2021-06...
# Processing AER: 2021-07...
# Processing AER: 2021-08...
# Processing AER: 2021-09...
# Processing AER: 2021-10...
# Processing AER: 2021-11...
# Processing AER: 2021-12...
# Processing AER: 2022-01...
# Processing AER: 2022-02...
# Processing AER: 2022-03...
# Processing AER: 2022-04...
# Processing AER: 2022-05...
# Processing AER: 2022-06...
# Processing AER: 2022-07...
# Processing AER: 2022-08...
# Processing AER: 2022-09...
# Processing AER: 2022-10...
# Processing AER: 2022-11...
# Processing AER: 2022-12...
# Processing AER: 2023-01...
# Processing AER: 2023-02...
# Processing AER: 2023-03...
# Processing AER: 2023-04...
# Processing AER: 2023-05...
# Processing AER: 2023-06...
# Processing AER: 2023-07...
# Processing AER: 2023-08...
# Processing AER: 2023-09...
# Processing AER: 2023-10...
# Processing AER: 2023-11...
# Processing AER: 2023-12...
# Processing AER: 2024-01...
# Processing AER: 2024-02...
# Processing AER: 2024-03...
# Processing AER: 2024-04...
# Processing AER: 2024-05...
# Processing AER: 2024-06...
# Processing AER: 2024-07...
# Processing AER: 2024-08...
# Processing AER: 2024-09...
# Processing AER: 2024-10...
# Processing AER: 2024-11...
# Processing AER: 2024-12...
# Processing AER: 2025-01...
# Processing CH4: 2020-01...
# Processing CH4: 2020-02...
# Processing CH4: 2020-03...
# Processing CH4: 2020-04...
# Processing CH4: 2020-05...
# Processing CH4: 2020-06...
# Processing CH4: 2020-07...
# Processing CH4: 2020-08...
# Processing CH4: 2020-09...
# Processing CH4: 2020-10...
# Processing CH4: 2020-11...
# Processing CH4: 2020-12...
# Processing CH4: 2021-01...
# Processing CH4: 2021-02...
# Processing CH4: 2021-03...
# Processing CH4: 2021-04...
# Processing CH4: 2021-05...
# Processing CH4: 2021-06...
# Processing CH4: 2021-07...
# Processing CH4: 2021-08...
# Processing CH4: 2021-09...
# Processing CH4: 2021-10...
# Processing CH4: 2021-11...
# Processing CH4: 2021-12...
# Processing CH4: 2022-01...
# Processing CH4: 2022-02...
# Processing CH4: 2022-03...
# Processing CH4: 2022-04...
# Processing CH4: 2022-05...
# Processing CH4: 2022-06...
# Processing CH4: 2022-07...
# Processing CH4: 2022-08...
# Processing CH4: 2022-09...
# Processing CH4: 2022-10...
# Processing CH4: 2022-11...
# Processing CH4: 2022-12...
# Processing CH4: 2023-01...
# Processing CH4: 2023-02...
# Processing CH4: 2023-03...
# Processing CH4: 2023-04...
# Processing CH4: 2023-05...
# Processing CH4: 2023-06...
# Processing CH4: 2023-07...
# Processing CH4: 2023-08...
# Processing CH4: 2023-09...
# Processing CH4: 2023-10...
# Processing CH4: 2023-11...
# Processing CH4: 2023-12...
# Processing CH4: 2024-01...
# Processing CH4: 2024-02...
# Processing CH4: 2024-03...
# Processing CH4: 2024-04...
# Processing CH4: 2024-05...
# Processing CH4: 2024-06...
# Processing CH4: 2024-07...
# Processing CH4: 2024-08...
# Processing CH4: 2024-09...
# Processing CH4: 2024-10...
# Processing CH4: 2024-11...
# Processing CH4: 2024-12...
# Processing CH4: 2025-01...
#
# Data collection summary:
# NO2: 61 months, 416 sectors, 25376 total records
# CO: 61 months, 416 sectors, 25376 total records
# SO2: 61 months, 416 sectors, 25376 total records
# O3: 61 months, 416 sectors, 25376 total records
# AER: 61 months, 416 sectors, 25376 total records
# CH4: 61 months, 416 sectors, 25376 total records
#
# Merging datasets...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27072\2133298346.py in ?()
# ----> 1 data = collect_air_quality_data(2020, 2025)
#
# ~\AppData\Local\Temp\ipykernel_27072\4107356891.py in ?(start_year, end_year)
#      84         }
#      85
#      86         # Merge remaining datasets one by one
#      87         for i, df in enumerate(non_empty_dfs[1:], 1):
# ---> 88             pollutant = ["NO2", "CO", "SO2", "O3", "AER", "CH4"][dfs.index(df)]
#      89             cols_to_use = ['Sect_ID', 'date'] + pollutant_cols[pollutant]
#      90             merged_df = merged_df.merge(
#      91                 df[cols_to_use], on=['Sect_ID', 'date'], how='outer')
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\ops\common.py in ?(self, other)
#      72                     return NotImplemented
#      73
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\arraylike.py in ?(self, other)
#      38     @unpack_zerodim_and_defer("__eq__")
#      39     def __eq__(self, other):
# ---> 40         return self._cmp_method(other, operator.eq)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py in ?(self, other, op)
#    7894     def _cmp_method(self, other, op):
#    7895         axis: Literal[1] = 1  # only relevant for Series other case
#    7896
# -> 7897         self, other = self._align_for_op(other, axis, flex=False, level=None)
#    7898
#    7899         # See GH#4537 for discussion of scalar op behavior
#    7900         new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py in ?(self, other, axis, flex, level)
#    8192                     left, right = left.align(
#    8193                         right, join="outer", level=level, copy=False
#    8194                     )
#    8195                 else:
# -> 8196                     raise ValueError(
#    8197                         "Can only compare identically-labeled (both index and columns) "
#    8198                         "DataFrame objects"
#    8199                     )
#
# ValueError: Can only compare identically-labeled (both index and columns) DataFrame objects
